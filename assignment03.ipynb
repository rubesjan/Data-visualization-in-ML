# %% [markdown]
# # Domácí úkol č. 3 - 📈 Vizualizace ve strojovém učení od A do Z
#
# ## 📚 Data
# Pro tento úkol si studenti **zvolí vhodná data sami**. ☝️ Zvolená data by měla být veřejně dostupná a měla by simulovat nebo odpovídat nějaké reálné situaci (tzn. syntetická/vygenerovaná data neuvažujeme!). Data si vybírejte tak, abyste na nich byli schopni řešit klasifikační nebo regresní úlohu (tedy supervizované učení, přítomnost výstupní proměnné).
#
# **Pro odvážné:** Pokud se cítíte silní v kramflecích, můžete si zvolit i nesupervizovanou úlohu, např. shlukování.
#
# #### Tipy na data a řešení
# V souboru datasets_tips.md můžete najít tipy na různé veřejné weby s datasety.
#
# Inspiraci pro vypracování úkolu najdete v praktických ukázkách k přednáškám č. 8 (cvičení 4) a 11. Nicméně pouze zkopírovaný kód nebude hodnocen kladně.
#
# ☝️**Pozor!** Zkuste si zvolit trochu nápaditý dataset. Pokud si zvolíte dataset, který je často součástí tutoriálů (např. [Titanic dataset](https://www.tensorflow.org/datasets/catalog/titanic) nebo [Iris dataset](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html#sklearn.datasets.load_iris)), pro zisk plného počtu bodů budete muset zřejmě vynaložit větší úsilí při jeho kreativní a neotřelé prezentaci.
#
# ## Zadání
# > ☝️ Používejte **markdown buňky**! Zdůvodňujte všechny důležité kroky, popisujte vizualizace a co je z nich možné pozorovat. Za nepřehledný domácí úkol nebudou uděleny body.
#
# Za řádné průběžné komentování a vizuální prezentaci postupu a výsledků lze získat až 5 bodů. Notebook odevzdávejte po spuštění (tzn. včetně output buněk) a zkrontrolujte si, že se komentáře korektně zobrazují ('rendered file' na GitLabu ve vašem prohlížeči).
#
# Úkol můžete vypracovávat jako **jednotlivci** nebo **ve skupině maximálně 3 spolužáků**. Postup pro hodnocení skupiny najdete na stránkách předmětu [zde](https://courses.fit.cvut.cz/BI-VIZ/homeworks/index.html#_podrobnosti-k-hodnocen%C3%AD-třet%C3%ADho-úkolu).
#
# ### Pokyny pro vypracování
#
# 🙏 Pokud je to možné, v každém bodě vaší práce **využijte vizualizace** a svá zjištění komentujte.
#
# **📖 Vaše úloha:**
# 1. Popište klasifikační/regresní úlohu, kterou v rámci domácího úkolu budete řešit.
# 2. Uveďte zdroj, odkud čerpáte data. ⛔️ Pozn.: Pokud pracujete s lokálně uloženým datasetem, odevzdejte jej spolu s vyřešeným Jupyter Notebookem prostřednictvím GitLabu. To aby s daty mohl pracovat i vyučující při opravě.
#
# **✨ Dataset:**
# V této části máte za úkol načíst zvolená data a pomocí vizualizace a popisných statistik se s nimi seznámit. Dále je nutné data vhodným způsobem předzpracovat, abyste je mohli použít pro trénování modelu.
# 1. Načtěte si zvolený dataset a importujte potřebné knihovny. Volba knihoven je na vás.
# 2. Představte jednotlivé příznaky pomocí textových popisů.
# 3. Analyzujte dataset pomocí popisných statistik s využitím vhodných vizualizačních metod. Svá zjištění komentujte.
# 4. Vyšetřete chybějící hodnoty (včetně jejich reprezentace) a odlehlá pozorování. Opět využijte vizualizace, pokud je to možné a svá zjištění komentujte.
# 5. Proveďte všechny další úpravy, které jsou podle vás pro práci s vybraným datasetem nezbytné (např. konverze datových typů, odstranění duplicitních údajů, vytvoření nových příznaků, sjednocení reprezentace chybějících dat nebo jejich odstranění apod.). K úpravě datasetu se můžete v průběhu řešení úlohy vracet.
# 6. Připravte dataset tak, abyste na něm mohli natrénovat a vyhodnotit vybraný model (např. data vhodně rozdělte, pokud je to pro váš model a evaluaci nutné, rozdělení komentujte, nebo můžete využít křížovou validaci apod. -> znáte z BI-ML1).
#
# Z této části lze získat celkem 7 bodů.
#
# **⚙️Model:**
# V této části je vaším úkolem natrénovat model, který se pokusí vyřešit vaši úlohu. Zaměřte se především na vizualizaci jednotlivých kroků a výsledků, včetně komentářů. Kvalita modelu jako takového nebude hodnocena.
# 1. Pro svoji úlohu zvolte vhodný klasifikační/regresní model.
# 2. Zvolte si alespoň dva hyperparametry spolu s minimálně pěti hodnotami (zde může být i více, případně méně v závislosti na zvoleném hyperparametru), jejichž nejlepší kombinaci budete během trénování modelu hledat. Zvolené hyperparametry a jejich hodnoty popište.
# 3. Zvolte a popište ztrátovou funkci, pomocí které provedete vyhodnocení úspěšnosti modelu.
# 4. Daný model na datasetu natrénujte. Pokud to lze, model vizualizujte.
# 5. Vhodně vizualizujte a komentujte vliv jednotlivých kombinací hyperparamentrů na úspěšnost modelu. Uveďte nejlepší kombinaci.
# 6. Pokud to lze (!), vizualizujte rozhodovací hranici modelu pro vámi vybrané příznaky (např. pouze pro 2). Pokud to nelze, zdůvodněte, případně realizujte jinou viualizaci související s prezentací nejlepšího modelu.
# 7. Vhodně vizualizujte úspěšnost výsledného modelu - využijte alespoň dvě vizualizační metody.
#
# **Pro zájemce:** Pokud byste chtěli, můžete pro řešení úlohy použít modelů více a provést jejich srovnání (včetně ladění hyperparametrů a dalších kroků zmíněných výše).
#
# Z této části lze získat celkem 18 bodů.
#
# ### Bodové hodnocení
# Shrnutí bodů, které můžete nejvýše získat:
# - 5 bodů za průběžné komentáře a vizuální prezentaci postupu a výsledků,
# - 7 bodů za předzpracování a prezentaci dat,
# - 18 bodů za trénování a vyhodnocení modelu.
#
# Celkem lze za domácí úkol č. 3 získat maximálně 30 bodů (každý člen týmu nebo jednotlivec).

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import pandas as pd
import numpy as np
import dtreeviz
import matplotlib.pyplot as plt

import sklearn.metrics as metrics
from sklearn.metrics import f1_score

from sklearn.model_selection import ParameterGrid
from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data
#
# Vybral jsem si data z https://www.kaggle.com/datasets/fedesoriano/heart-failure-prediction
#
# Jedná se o předpovídání, zda pacient bude mít srdeční chorobu na základě 11 příznaků.
#
# Dataset je spojen z 5 datasetů a obsahuje celkem 918 unikátních záznamů.
#
# celý dataset je dostupný zde:
# https://www.kaggle.com/datasets/fedesoriano/heart-failure-prediction
#
# příznaky:
#
#     Age: age of the patient [years]
#     Sex: sex of the patient [M: Male, F: Female]
#     ChestPainType: chest pain type [TA: Typical Angina, ATA: Atypical Angina, NAP: Non-Anginal Pain, ASY: Asymptomatic]
#     RestingBP: resting blood pressure [mm Hg]
#     Cholesterol: serum cholesterol [mm/dl]
#     FastingBS: fasting blood sugar [1: if FastingBS > 120 mg/dl, 0: otherwise]
#     RestingECG: resting electrocardiogram results [Normal: Normal, ST: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV), LVH: showing probable or definite left ventricular hypertrophy by Estes' criteria]
#     MaxHR: maximum heart rate achieved [Numeric value between 60 and 202]
#     ExerciseAngina: exercise-induced angina [Y: Yes, N: No]
#     Oldpeak: oldpeak = ST [Numeric value measured in depression]
#     ST_Slope: the slope of the peak exercise ST segment [Up: upsloping, Flat: flat, Down: downsloping]
#     HeartDisease: output class [1: heart disease, 0: Normal]
#
# načtení dat:

# %%
# https://www.kaggle.com/datasets/fedesoriano/heart-failure-prediction

data = pd.read_csv("heart.csv")
display(data.info())
print("="*40)
print("number of rows with nan:", len(data) - len(data.dropna()))

print("="*40)
print(f"number of duplicated rows: {len(data) - len(data.drop_duplicates())}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB
# None
# ...
# number of rows with nan: 0
# ...
# number of duplicated rows: 0

# %% [markdown]
# je vidět, že v datech nejsou žádné chybějící hodnoty ani duplikované záznamy, většina sloupců je číselná
#
# Nejdříve si data rozdělím na příznaky a vysvětlovanou proměnnou, pak na testovací a trénovací. Trénovací data dále prozkoumám:

# %%
x = data.drop(["HeartDisease"], axis=1)
y = data["HeartDisease"]

random_seed = 98424987

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=random_seed)

# %%
data = xtrain

display(data.info())

print("="*40)
display(data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 734 entries, 701 to 646
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             734 non-null    int64
#  1   Sex             734 non-null    object
#  2   ChestPainType   734 non-null    object
#  3   RestingBP       734 non-null    int64
#  4   Cholesterol     734 non-null    int64
#  5   FastingBS       734 non-null    int64
#  6   RestingECG      734 non-null    object
#  7   MaxHR           734 non-null    int64
#  8   ExerciseAngina  734 non-null    object
#  9   Oldpeak         734 non-null    float64
#  10  ST_Slope        734 non-null    object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 68.8+ KB
# None
# ...
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR     Oldpeak
# count  734.000000  734.000000   734.000000  734.000000  734.000000  734.000000
# ...

# %% [markdown]
# z tabulky výše je vidět jaké hodnoty obsahují sloupce
#
# pro detailnější analýzu jsem vykreslil boxplot pro všechny sloupce obsahující číselná data:

# %%
fig, ax = plt.subplots(figsize=(12, 8), nrows=2, ncols=3)

columns = data.select_dtypes(["int64", "float64"])
columns = set(columns)

for i, col in enumerate(columns):
    ax[i%2, i%3].boxplot(data[col])
    ax[i%2, i%3].set_title(f"{col}")
    ax[i%2, i%3].grid(axis='y', color='black', alpha=0.3, linewidth=0.5)
    ax[i%2, i%3].set_xticklabels([""])

pass

# %% [markdown]
# Z grafů výše je vidět rozložení hodnot jednotlivých příznaků. Lze si všimnout například toho, že v datech jsou záznamy o lidech starých 30-75 let. Očekával bych, že medián věku bude vyšší.
#
# zobrazení object sloupců a jejich hodnot:

# %%
for column in data.select_dtypes(include='object').columns:
    display(data[column].groupby(data[column]).count())
    print("="*40)
# Out:
# Sex
# F    151
# M    583
# Name: Sex, dtype: int64
# ...
# ChestPainType
# ASY    407
# ATA    138
# NAP    151
# TA      38
# Name: ChestPainType, dtype: int64
# ...
# RestingECG
# LVH       142
# Normal    443
# ST        149
# Name: RestingECG, dtype: int64
# ...
# ExerciseAngina
# N    441
# Y    293
# Name: ExerciseAngina, dtype: int64
# ...
# ST_Slope
# Down     50
# Flat    368
# Up      316
# Name: ST_Slope, dtype: int64
# ...

# %% [markdown]
# převedení sloupců typu object na číselnou reprezentaci:
#
# ExerciseAngina obsahuje binární data z popisu na Kaggle
#
# ST_Slope obsahuje oridnální data, takže ho převedu na číselnou reprezentaci

# %%
# train dataset
xtrain["ExerciseAngina"].replace({"Y":1, "N":0}, inplace=True)

slope_category = pd.api.types.CategoricalDtype(categories=["Up", "Flat", "Down"], ordered=True)
xtrain["ST_Slope"] = xtrain["ST_Slope"].astype(slope_category)
xtrain["ST_Slope"] = xtrain["ST_Slope"].cat.codes

# test dataset
xtest["ExerciseAngina"].replace({"Y":1, "N":0}, inplace=True)

slope_category = pd.api.types.CategoricalDtype(categories=["Up", "Flat", "Down"], ordered=True)
xtest["ST_Slope"] = xtest["ST_Slope"].astype(slope_category)
xtest["ST_Slope"] = xtest["ST_Slope"].cat.codes

# %% [markdown]
# převedení zbylých object sloupců na číselnou reprezentaci pomocí one hot encoding:

# %%
# train dataset
xtrain["Sex"] = xtrain["Sex"].replace({"M": 1, "F":0})
xtrain.rename({"Sex": "Male"}, inplace=True)

xtrain = pd.get_dummies(xtrain, columns=xtrain.select_dtypes(include='object').columns)
xtrain.replace({False: 0, True: 1}, inplace=True)

# test dataset
xtest["Sex"] = xtest["Sex"].replace({"M": 1, "F":0})
xtest.rename({"Sex": "Male"}, inplace=True)

xtest = pd.get_dummies(xtest, columns=xtest.select_dtypes(include='object').columns)
xtest.replace({False: 0, True: 1}, inplace=True)

data = xtrain
display(data.info())
print(f"data shape: {data.shape}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 734 entries, 701 to 646
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                734 non-null    int64
#  1   Sex                734 non-null    int64
#  2   RestingBP          734 non-null    int64
#  3   Cholesterol        734 non-null    int64
#  4   FastingBS          734 non-null    int64
#  5   MaxHR              734 non-null    int64
#  6   ExerciseAngina     734 non-null    int64
#  7   Oldpeak            734 non-null    float64
#  8   ST_Slope           734 non-null    int8
#  9   ChestPainType_ASY  734 non-null    int64
#  10  ChestPainType_ATA  734 non-null    int64
#  11  ChestPainType_NAP  734 non-null    int64
#  12  ChestPainType_TA   734 non-null    int64
#  13  RestingECG_LVH     734 non-null    int64
#  14  RestingECG_Normal  734 non-null    int64
#  15  RestingECG_ST      734 non-null    int64
# ...

# %% [markdown]
# rozdělení trénovacích dat na validační a trénovací:

# %%
xtrain, xval, ytrain, yval = train_test_split(xtrain, ytrain, test_size=0.25, random_state=random_seed)

# %% [markdown]
# # Trénování modelu
#
# Vybral jsem si model rozhodovacího stromu. Myslím si, že je pro tuto úlohu je vhodný a dá se i vizualizovat.
# Budu hledat nejlepší hodnotu těchto hyperparametrů:
#
#     max_depth - <3, 15) - maximální hloubka stromu, čím je větší, tím více  se strom může přeučit
#     min_samples_leaf - <2, 10) - minimální počet záznamů v každém listu
#     criterion - {gini, entropy} - kritérium na hodnocení neuspořádanosti v množině (vysvětlované proměnné)
#
#
# jako ztrátovou funkci použiji binary cross-entropy loss:
#
#     L(y,p)= -y⋅log(p) - (1-y)⋅log(1−p)
#
# hledání nejlepších hyperparamtrů modelu:

# %%
hyperparams = {
    "max_depth": range(3, 15),
    "min_samples_leaf": range(2, 10),
    "criterion": ["gini", "entropy"]
}

val_loss = []

hyperparams = ParameterGrid(hyperparams)

for param in hyperparams:
    tree = DecisionTreeClassifier(**param, random_state=random_seed)
    tree.fit(xtrain, ytrain)
    ypred = tree.predict_proba(xval)
    val_loss.append(metrics.log_loss(yval, ypred))

# %% [markdown]
# vypsání nejnižší cross-entropy a nejlepších hyperparametrů:

# %%
def get_argmin(l):
    m = np.min(l)
    res = []
    for i in range(len(l)):
        if m == l[i]:
            res.append(i)
    return res

best_params = get_argmin(val_loss)
best_params = [hyperparams[i] for i in best_params]

print(f"Minimální cross-entropy loss: {round(np.min(val_loss), 4)}")
print("\nNejlepší hyperparametry:")
for param in best_params:
    print(param)

val_loss = np.min(val_loss)
# Out:
# Minimální cross-entropy loss: 0.5297
#
# Nejlepší hyperparametry:
# {'min_samples_leaf': 2, 'max_depth': 3, 'criterion': 'gini'}

# %% [markdown]
# zde je vidět, že ztrátová funkce nabývá nejmenší hodnoty pro tyto hyperparametry

# %%
best_params = best_params[-1]

# %% [markdown]
# # Vizualizace modelu

# %%
fig, ax = plt.subplots(figsize=(12, 9))

tree = DecisionTreeClassifier(**best_params, random_state=random_seed)
tree.fit(xtrain, ytrain)

val_acc = metrics.accuracy_score(yval, tree.predict(xval))

plot_tree(tree, filled=True, feature_names=xtrain.columns, rounded=True, precision=2, max_depth=3, class_names=True)

pass

# %% [markdown]
# # Vizualizace rozhodovacích hranic na trénovacích datech

# %%
tree = DecisionTreeClassifier(**best_params, random_state=random_seed)
tree.fit(xtrain, ytrain)

viz = dtreeviz.model(tree, xtrain, ytrain,
           target_name="HeartDisease",
           feature_names=xtrain.columns.tolist(),
           class_names=[1, 0])

viz.view(fontname="monospace")

# %% [markdown]
# Z výstupu výše je vidět, jak se dělí trénovací data podle jednotlivých příznaků a jaký je poměr výstupních tříd v listech. Je zajímavé vidět, jak rozhodovací hranice rozdělí data v histogramu.
#
# Vizualizace na dvou příznacích není možná v tomto případě, protože strom má větší hloubku než 2 a výsledná predikce tedy závisí na více příznacích. Myslím si ale, že tato vizualizace velice dobře zobrazuje strom s rozhodovacími hranicemi a jak tyto hranice rozdělují data.

# %% [markdown]
# # Závislost úspěšnosti modelu na hyperparametrech

# %%
print(best_params)
# Out:
# {'min_samples_leaf': 2, 'max_depth': 3, 'criterion': 'gini'}

# %%
train_loss = []
val_gini_loss = []
val_entropy_loss = []

for depth in range(1, 16):
    tree = DecisionTreeClassifier(max_depth=depth, criterion="entropy", random_state=random_seed)
    tree.fit(xtrain, ytrain)
    val_entropy_loss.append(metrics.log_loss(yval, tree.predict_proba(xval)))

    tree = DecisionTreeClassifier(max_depth=depth, criterion="gini", random_state=random_seed)
    tree.fit(xtrain, ytrain)
    train_loss.append(metrics.log_loss(ytrain, tree.predict_proba(xtrain)))
    val_gini_loss.append(metrics.log_loss(yval, tree.predict_proba(xval)))

# %%
fig, ax = plt.subplots(figsize=(11, 6))
ax.plot(val_entropy_loss, 'ob-')
ax.plot(val_gini_loss, "or-")
ax.plot(train_loss, "og-")

ax.grid(axis='y', color='black', alpha=0.2, linewidth=0.5)
ax.set_xticks(range(0,15), range(1,16))
ax.set_ylabel("Validation cross-entropy loss")
ax.set_xlabel("Max depth")
plt.legend(["entropy val.", "gini val.", "gini train"])
ax.set_title("Dependency of cross-entropy loss on max_depth")

best_gini_depth = np.argmin(val_gini_loss) + 1
best_entropy_depth = np.argmin(val_entropy_loss) + 1

print("Best gini depth (without using min_samples_leaf parameter):", np.argmin(val_gini_loss) + 1)
print(f"Lowest validation cross-entropy loss: {round(np.min(val_gini_loss), 2)}\n")
print("Best entropy depth (without using min_samples_leaf parameter):", np.argmin(val_entropy_loss) + 1)
print(f"Lowest validation cross-entropy loss: {round(np.min(val_entropy_loss), 2)}")
# Out:
# Best gini depth (without using min_samples_leaf parameter): 2
# Lowest validation cross-entropy loss: 0.5
#
# Best entropy depth (without using min_samples_leaf parameter): 2
# Lowest validation cross-entropy loss: 0.5

# %% [markdown]
# Zde je vidět, že s rostoucí hloubkou stromu klesá ztrátová funkce na trénovacích dat, ale naopak roste na validačních datech - dochází k přeučení. Z grafu je vidět, že pro tyto data je lepší menší hloubka 2-3. Já jsem jako dolní hranici při hledání nejlepší maximální hloubky nastavil hodnotu 3, protože si myslím, že hloubka 2 je moc nízká.

# %%
# preparation for graph

val_gini_loss = []
val_entropy_loss = []

for leaf in range(1, 10):
    tree = DecisionTreeClassifier(max_depth=3, criterion="gini", min_samples_leaf=leaf, random_state=random_seed)
    tree.fit(xtrain, ytrain)
    val_gini_loss.append(metrics.log_loss(yval, tree.predict_proba(xval)))
    
    tree = DecisionTreeClassifier(max_depth=3, criterion="entropy", min_samples_leaf=leaf, random_state=random_seed)
    tree.fit(xtrain, ytrain)
    val_entropy_loss.append(metrics.log_loss(yval, tree.predict_proba(xval)))

# %%
fig, ax = plt.subplots(figsize=(11, 6))
ax.plot(val_entropy_loss, 'ob-')
ax.plot(val_gini_loss, "or-")

ax.grid(axis='y', color='black', alpha=0.2, linewidth=0.5)
ax.set_xticks(range(0,9), range(1,10))
ax.set_ylabel("Validation cross-entropy loss")
ax.set_xlabel("Min samples leaf")
plt.legend(["entropy (max_deph=3)", "gini (max_depth=3)"])
ax.set_title("Dependency of cross-entropy loss on min_samples_leaf")

print("best gini min_sample_leafs value:", np.argmin(val_gini_loss) + 1)
print(f"Lowest cross-entropy loss: {round(np.min(val_gini_loss), 4)} \n")

print("best entropy min_sample_leafs value:", np.argmin(val_entropy_loss) + 1)
print(f"Lowest cross-entropy loss: {round(np.min(val_entropy_loss), 4)}")
# Out:
# best gini min_sample_leafs value: 1
# Lowest cross-entropy loss: 0.5268
#
# best entropy min_sample_leafs value: 1
# Lowest cross-entropy loss: 0.5305

# %% [markdown]
# Z tohoto grafu je vidět jak se mění hodnota ztrátové funkce na validační množině s rostoucí hodnotou hyperparametru min_samples_leaf. Je vidět, že při využití entropie má ztrátová funkce stejnou hodnotu, ale při využití gini indexu roste. Z grafu to vypadá, že nejlepší hodnota je jedna, ale opět při hledání nejlepších hyperparamtrů jsem nastavil dolní hranici min_samples_leaf na 2.

# %% [markdown]
# # Evaluace modelu
#
# Pro finální model si spojím trénovací a validační množinu a výsledný model na trénuju na co nejvíce datech s nejlepšími hyperparamtry.
#
# Poté si připravím data na vykreslení ROC křivky a vykreslení matice záměn:

# %%
x = pd.concat([xval, xtrain], axis=0)
y = pd.concat([yval, ytrain], axis=0)

clf = DecisionTreeClassifier(**best_params, random_state=random_seed)
clf.fit(x, y)
ypredicted = clf.predict(xtest)

ptest = clf.predict_proba(xtest)
ptest = ptest[:, 1]

# accuracy and cross-entropy loss
test_loss = metrics.log_loss(ytest, clf.predict_proba(xtest))
accuracy = metrics.accuracy_score(ypredicted, ytest)

# ROC curve
fpr, tpr, tresholds = metrics.roc_curve(ytest, ptest)
auc = metrics.auc(fpr, tpr)
fscore = f1_score(ytest, ypredicted)

# confusion matrix
ypred = clf.predict(xtest)
cmatrix = metrics.confusion_matrix(ytest, ypred)

# PR curve
precision, recall, tresholds = metrics.precision_recall_curve(ytest, ptest)

pass

# %% [markdown]
# vykreslení ROC křivky a výsledných vlastností modelu:

# %%
fig, ax = plt.subplots()

ax.plot(fpr, tpr, color="red", lw=2)
ax.set_title("ROC Curve", fontsize=18)
ax.plot([0,1], [0,1], color="lightblue", linestyle="--")
plt.ylim([0,1])
plt.xlim([0, 1])
ax.set_ylabel("True positive rate", fontsize=13)
ax.set_xlabel("False positive rate", fontsize=13)

print(f"Validation cross-entropy loss: {round(val_loss, 2)}")
print(f"Test cross-entropy loss: {round(test_loss, 2)}")
print(f"\nValidation accuracy: {round(val_acc*100, 2)}%")
print(f"Test accuracy: {round(accuracy*100, 2)}%")
print("\nF1 score:", round(fscore, 4))
print("AUC:", round(auc, 4))
pass
# Out:
# Validation cross-entropy loss: 0.53
# Test cross-entropy loss: 0.32
#
# Validation accuracy: 77.72%
# Test accuracy: 88.04%
#
# F1 score: 0.8942
# AUC: 0.9325

# %% [markdown]
# Z výstupu výše je vidět validační i testovací přesnost včetně hodnoty ztrátové funkce. Je zajímavé, že obojí je lepší u testovací množiny. Jeden z důvodů je to, že při testování výsledné testovací přesnosti, jsem spojil trénovací a validační množinu a model tak měl k dispozici více dat k učení.
#
# Výsledná testovací přesnost je 88% - takovou přenost lze očekávat na nových datech.
#
# Vysvětlovaná proměnná byla v datech zastoupena rovnoměrně. Myslím si, že to nelze očekávat v praxi, takže to je třeba vzít v úvahu.
#
#
# matice záměn:

# %%
fig, ax = plt.subplots()
table = ax.table(cellText = cmatrix, rowLabels = ["Predicted 1", "Predicted 0"],
                 colLabels = ["Real val. 1", "Real val. 0"], loc="upper center",
                colColours=[(0.5804, 0.8196, 0.6196)]*2, rowColours=[(0.5804, 0.6353, 0.8196)]*5)

ax.set_title("Confusion matrix", fontsize=15)
ax.axis("off")
table.scale(0.5, 4)
table.set_fontsize(14)

# %% [markdown]
# Z výstupu výše je vidět, že špatně predikované hodnoty jsou rovnoměrně rozložené mezi false positive a false negative.

# %%
fig, ax = plt.subplots()

ax.plot(precision, recall)

ax.set_title("Precision-recall graph", fontsize=15)
ax.set_ylabel("Precision", fontsize=13)
ax.set_xlabel("Recall", fontsize=13)

plt.ylim([0,1])
plt.xlim([0, 1])

pass
